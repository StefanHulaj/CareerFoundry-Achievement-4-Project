# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\stefa\Documents\07-Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\stefa\\Documents\\07-Instacart Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'),  index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'),  index_col = False)

# %%
df_ords = df_ords.drop(columns = ['Unnamed: 0'])
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        orders_time_of_day (24 hours)  days_since_prior_order
# count                   3.421083e+06            3.214874e+06
# mean                    1.345202e+01            1.111484e+01
# std                     4.226088e+00            9.206737e+00
# min                     0.000000e+00            0.000000e+00
# ...

# %%
# Create a dataframe
df_test = pd.DataFrame()

# %% [markdown]
# Finding mixed data types

# %%
# Create a mixed test column
df_test['mix'] = ['a', 'b', 1, True]

# %%
# Display head of df_test dataframe
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types

for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\stefa\AppData\Local\Temp\ipykernel_21568\1522843687.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
# Change variable type from int64 to string
df_test['mix'] = df_test['mix'].astype('str')

# %% [markdown]
# Finding missing values

# %%
# Finding missing values in df_prods dataframe
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Finding the shape of df_prods dataframe
df_prods.shape
# Out:
# (49693, 5)

# %%
# Creating new dataframe df_prods_clean
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
# Finding the shape of df_prods_clean dataframe
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# Finding duclicate data

# %%
# Looking for duplicates in df_prods_clean dataframe
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
## Creating new dataframe df_prods_clean_no_dups
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))

# %% [markdown]
# All previous code was for practicing applying data consistency checks using the df_prods data set. The code below is for completing task 4.5

# %%
# Step 2
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        orders_time_of_day (24 hours)  days_since_prior_order
# count                   3.421083e+06            3.214874e+06
# mean                    1.345202e+01            1.111484e+01
# std                     4.226088e+00            9.206737e+00
# min                     0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# I can not find any anomalies with the df_ords dataframe.

# %%
# Step 3
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].map(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %%
# Step 4

# %% [markdown]
# There are no mixed data types in the df_ords dataset.

# %%
# Step 5
df_ords.isnull().sum()
# Out:
# order_id                              0
# user_id                               0
# order_number                          0
# orders_day_of_week                    0
# orders_time_of_day (24 hours)         0
# days_since_prior_order           206209
# dtype: int64

# %%
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# There are 206209 null entries in the df_orbs dataframe. These null entries are all in the days_since_prior_order column. The reason for these missing entries I believe is that those enteries were input incorrectly, missing the information about how long it had been since a customer ordered previously. Therefore, we are seeing gaps in our dataframe.

# %%
# Step 6
df_mis = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_mis
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 11        2168274        2             1                   2
# 26        1374495        3             1                   1
# 39        3343014        4             1                   6
# 45        2717275        5             1                   3
# ...           ...      ...           ...                 ...
# 3420930    969311   206205             1                   4
# 3420934   3189322   206206             1                   3
# 3421002   2166133   206207             1                   6
# 3421019   2227043   206208             1                   1
# 3421069   3154581   206209             1                   3
#
#          orders_time_of_day (24 hours)  days_since_prior_order
# 0                                    8                     NaN
# 11                                  11                     NaN
# ...

# %%
df_mis.head(30)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  \
# 0     2539329        1             1                   2
# 11    2168274        2             1                   2
# 26    1374495        3             1                   1
# 39    3343014        4             1                   6
# 45    2717275        5             1                   3
# 50    2086598        6             1                   5
# 54    2565571        7             1                   3
# 75     600894        8             1                   6
# 79     280530        9             1                   1
# 83    1224907       10             1                   2
# 89    2411567       11             1                   0
# 97    1483446       12             1                   1
# 103   2618231       13             1                   6
# 116   2906263       14             1                   2
# 130   2514324       15             1                   5
# ...

# %%
df_mis.tail(30)
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 3420548    566068   206180             1                   0
# 3420567    351920   206181             1                   0
# 3420582    485448   206182             1                   0
# 3420593     31169   206183             1                   0
# 3420608    180109   206184             1                   6
# 3420613   2168901   206185             1                   5
# 3420624   1831589   206186             1                   6
# 3420628    474057   206187             1                   2
# 3420663   1944921   206188             1                   4
# 3420671   2966736   206189             1                   4
# 3420678   1955107   206190             1                   6
# 3420687    936117   206191             1                   6
# 3420693   3242108   206192             1                   6
# 3420708    313609   206193             1                   5
# ...

# %% [markdown]
# There is no need to replace the NaN values in the days_since_prior_order column of the df_ords dataframe. I was incorrect in my reasoning to why the days_since_prior_order column has NaN values. The data shows the rows that have NaN data in their days_since_prior_order column are first time orders, meaning there is no prior date to pull from.

# %%
# Step 7
df_dups_ords = df_ords[df_ords.duplicated()]

# %%
df_dups_ords
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, orders_time_of_day (24 hours), days_since_prior_order]
# Index: []

# %%
# Step 8

# %% [markdown]
# There seem to be no duplicates in the df_ords data frame.

# %%
# Step 9
df_ords
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          orders_time_of_day (24 hours)  days_since_prior_order
# 0                                    8                     NaN
# 1                                    7                    15.0
# ...

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_checked.csv'))

# %%
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'products_checked.csv'))
